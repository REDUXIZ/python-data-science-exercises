# %%
import pandas as pd
import requests

# %%
pd.__version__
# Out:
# '2.3.1'

# %%
#colab
#NBA results

download_url = 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/nba-elo/nbaallelo.csv'
target_csv = 'nba_all_elo.csv'

response = requests.get(download_url)
response.raise_for_status()

with open(target_csv , 'wb') as file :
     file.write(response.content)

# %%
#jupyter notebook

nba = pd.read_csv(r"E:\Python video\ML WITH REZA\FILES\nbaallelo.csv")
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
type(nba)
# Out:
# pandas.core.frame.DataFrame

# %%
len(nba)
# Out:
# 126314

# %%
nba.shape
# Out:
# (126314, 23)

# %%
nba.head()
nba.sample(10)
nba.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# ...

# %%
pd.set_option('display.max.columns' , None)
pd.set_option('display.precision' , 5)

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233   41.70517    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521   42.01226    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712   40.69278    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189   38.86405    WSC
#
# ...

# %%
nba.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
type(nba.columns) #Index
# Out:
# pandas.core.indexes.base.Index

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
type(nba.index) #RangeIndex
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
nba.iloc[30:51:2]
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 30         16  194611090PRO   NBA        0     1947   11/9/1946           3
# 32         17  194611090STB   NBA        0     1947   11/9/1946           4
# 34         18  194611100CLR   NBA        0     1947  11/10/1946           2
# 36         19  194611110NYK   NBA        1     1947  11/11/1946           5
# 38         20  194611110PIT   NBA        0     1947  11/11/1946           5
# 40         21  194611130CHS   NBA        1     1947  11/13/1946           4
# 42         22  194611130DTF   NBA        0     1947  11/13/1946           5
# 44         23  194611140GSW   NBA        0     1947  11/14/1946           2
# 46         24  194611140STB   NBA        1     1947  11/14/1946           5
# 48         25  194611150TRH   NBA        1     1947  11/15/1946           6
# 50         26  194611160BOS   NBA        1     1947  11/16/1946           6
#
# ...

# %%
nba.iloc[0 : 11 : 2, 4 : 8]
# Out:
#     year_id  date_game  seasongame  is_playoffs
# 0      1947  11/1/1946           1            0
# 2      1947  11/2/1946           1            0
# 4      1947  11/2/1946           1            0
# 6      1947  11/2/1946           1            0
# 8      1947  11/2/1946           1            0
# 10     1947  11/3/1946           2            0

# %%
my_columns = ['gameorder' ,'date_game' , 'game_result']

# %%
nba.loc[0 : 8 : 2  , my_columns]
# Out:
#    gameorder  date_game game_result
# 0          1  11/1/1946           L
# 2          2  11/2/1946           W
# 4          3  11/2/1946           L
# 6          4  11/2/1946           L
# 8          5  11/2/1946           L

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
nba.describe()
# Out:
#           gameorder   _iscopy       year_id    seasongame   is_playoffs  \
# count  126314.00000  126314.0  126314.00000  126314.00000  126314.00000
# mean    31579.00000       0.5    1988.20037      43.53373       0.06386
# std     18231.92764       0.5      17.58231      25.37518       0.24450
# min         1.00000       0.0    1947.00000       1.00000       0.00000
# 25%     15790.00000       0.0    1975.00000      22.00000       0.00000
# 50%     31579.00000       0.5    1990.00000      43.00000       0.00000
# 75%     47368.00000       1.0    2003.00000      65.00000       0.00000
# max     63157.00000       1.0    2015.00000     108.00000       1.00000
#
#                 pts         elo_i         elo_n     win_equiv       opp_pts  \
# count  126314.00000  126314.00000  126314.00000  126314.00000  126314.00000
# mean      102.72998    1495.23606    1495.23606      41.70789     102.72998
# std        14.81484     112.13995     112.46169      10.62733      14.81484
# ...

# %%
type(nba.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
nba.describe().shape
# Out:
# (8, 13)

# %%
nba.describe(include = 'object')
# Out:
#              game_id   lg_id  date_game team_id fran_id  opp_id opp_fran  \
# count         126314  126314     126314  126314  126314  126314   126314
# unique         63157       2      12426     104      53     104       53
# top     194611010TRH     NBA  4/17/2013     BOS  Lakers     BOS   Lakers
# freq               2  118016         30    5997    6024    5997     6024
#
#        game_location game_result           notes
# count         126314      126314            5424
# unique             3           2             231
# top                H           L  at New York NY
# freq           63138       63157             440

# %%
nba['lg_id']
# Out:
# 0         NBA
# 1         NBA
# 2         NBA
# 3         NBA
# 4         NBA
#          ...
# 126309    NBA
# 126310    NBA
# 126311    NBA
# 126312    NBA
# 126313    NBA
# Name: lg_id, Length: 126314, dtype: object

# %%
nba.lg_id
# Out:
# 0         NBA
# 1         NBA
# 2         NBA
# 3         NBA
# 4         NBA
#          ...
# 126309    NBA
# 126310    NBA
# 126311    NBA
# 126312    NBA
# 126313    NBA
# Name: lg_id, Length: 126314, dtype: object

# %%
print(nba.pts.max())
print(nba.pts.mode())
print(nba.pts.mean())
print(nba.pts.std())
print(nba.pts.median())
print(nba.pts.sum()) #...
# Out:
# 186
# 0    102
# Name: pts, dtype: int64
# 102.72998242475101
# 14.81484465438624
# 103.0
# 12976235

# %%
nba.team_id.value_counts()
# Out:
# team_id
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# PIT      60
# INJ      60
# TRH      60
# DTF      60
# SDS      11
# Name: count, Length: 104, dtype: int64

# %%
nba.fran_id.value_counts()
# Out:
# fran_id
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
#Querying :

# %%
nba['fran_id'] == 'Lakers'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309    False
# 126310    False
# 126311    False
# 126312    False
# 126313    False
# Name: fran_id, Length: 126314, dtype: bool

# %%
nba[nba['fran_id'] == 'Lakers'] #just true
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1136          569  194811040BLB   NBA        1     1949   11/4/1948
# 1152          577  194811060WSC   NBA        1     1949   11/6/1948
# 1159          580  194811090BOS   NBA        1     1949   11/9/1948
# 1170          586  194811110NYK   NBA        1     1949  11/11/1948
# 1183          592  194811130PRO   NBA        1     1949  11/13/1948
# ...           ...           ...   ...      ...      ...         ...
# 126016      63009  201504080DEN   NBA        1     2015    4/8/2015
# 126052      63027  201504100LAL   NBA        0     2015   4/10/2015
# 126086      63044  201504120LAL   NBA        0     2015   4/12/2015
# 126115      63058  201504130SAC   NBA        1     2015   4/13/2015
# 126137      63069  201504150LAL   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# ...

# %%
nba.loc[nba['fran_id'] == 'Lakers' , 'team_id'].value_counts()
# Out:
# team_id
# LAL    5078
# MNL     946
# Name: count, dtype: int64

# %%
nba[nba.pts == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 26684      13343  197210260VIR   ABA        1     1973  10/26/1972
#
#        seasongame  is_playoffs team_id  fran_id  pts      elo_i      elo_n  \
# 26684           7            0     DNR  Nuggets    0  1460.3387  1457.4464
#
#        win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location  \
# 26684   40.40886    VIR  Squires        2  1484.1907   1487.083             A
#
#       game_result  forecast                           notes
# 26684           L   0.32895  at Richmond VA; forfeit to VIR

# %%
nba[nba.gameorder == 13343]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 26684      13343  197210260VIR   ABA        1     1973  10/26/1972
# 26685      13343  197210260VIR   ABA        0     1973  10/26/1972
#
#        seasongame  is_playoffs team_id  fran_id  pts      elo_i      elo_n  \
# 26684           7            0     DNR  Nuggets    0  1460.3387  1457.4464
# 26685           8            0     VIR  Squires    2  1484.1907  1487.0830
#
#        win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location  \
# 26684   40.40886    VIR  Squires        2  1484.1907  1487.0830             A
# 26685   43.51441    DNR  Nuggets        0  1460.3387  1457.4464             H
#
#       game_result  forecast                           notes
# 26684           L   0.32895  at Richmond VA; forfeit to VIR
# 26685           W   0.67105  at Richmond VA; forfeit to VIR

# %%
nba[nba.pts >= 180]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 50094      25048  198312130DEN   NBA        1     1984  12/13/1983
# 50095      25048  198312130DEN   NBA        0     1984  12/13/1983
#
#        seasongame  is_playoffs team_id  fran_id  pts      elo_i      elo_n  \
# 50094          23            0     DET  Pistons  186  1491.8865  1499.0237
# 50095          23            0     DEN  Nuggets  184  1512.6967  1505.5594
#
#        win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location  \
# 50094   40.80094    DEN  Nuggets      184  1512.6967  1505.5594             A
# 50095   41.48649    DET  Pistons      186  1491.8865  1499.0237             H
#
#       game_result  forecast notes
# 50094           W   0.33282   NaN
# 50095           L   0.66718   NaN

# %%
nba[nba.pts > 120]
print(nba[nba.pts > 120].shape)
# Out:
# (14215, 23)

# %%
nba.is_playoffs == 1
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309     True
# 126310     True
# 126311     True
# 126312     True
# 126313     True
# Name: is_playoffs, Length: 126314, dtype: bool

# %%
nba[(nba.pts > 120 ) & (nba.is_playoffs == 1)].shape
# Out:
# (712, 23)

# %%
nba[(nba.pts < 45 ) | (nba.pts > 180 )].shape
# Out:
# (15, 23)

# %%
nba.date_game
# Out:
# 0         11/1/1946
# 1         11/1/1946
# 2         11/2/1946
# 3         11/2/1946
# 4         11/2/1946
#             ...
# 126309    6/11/2015
# 126310    6/14/2015
# 126311    6/14/2015
# 126312    6/16/2015
# 126313    6/16/2015
# Name: date_game, Length: 126314, dtype: object

# %%
nba.date_game.min()
# Out:
# '1/1/1947'

# %%
nba['date_timestamp'] = pd.to_datetime(nba.date_game)

# %%
nba.shape
# Out:
# (126314, 24)

# %%
nba.date_timestamp.min()
# Out:
# Timestamp('1946-11-01 00:00:00')
